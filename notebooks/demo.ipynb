# %%
import spacy
import os
import json
import pandas as pd
import time

# %%
CSV = "extracted_entities.csv"

# %%
# Load spaCy's multilingual model (supports Ukrainian)
print("[INFO] Loading spaCy model...")
nlp = spacy.load("xx_ent_wiki_sm")  # Faster Ukrainian-only model

nlp.enable_pipe("ner")  # Ensure NER is enabled

if spacy.prefer_gpu():
    print("[INFO] Using GPU acceleration for spaCy.")
else:
    print("[INFO] Running on CPU.")
# Out:
# [INFO] Loading spaCy model...
# [INFO] Using GPU acceleration for spaCy.

# %%
BATCH_SIZE = 100  # Save progress every 100 articles

# %%
# Function to extract named entities from text using spaCy
def extract_entities_from_text(text):
    """Extract named entities using spaCy."""
    try:
        doc = nlp(text)
        return [{'text': ent.text, 'label': ent.label_} for ent in doc.ents]
    except Exception as e:
        print(f"[ERROR] NER processing failed: {e}")
        return []

# Process and save entities in chunks
def process_articles(directory):
    """Loads, processes, and saves articles in chunks to reduce memory usage."""
    article_count = 0
    extracted_data = []
    start_time = time.time()

    print(f"[INFO] Starting entity extraction from {directory}...")

    # Walk through all files in the directory
    for root, _, files in os.walk(directory):
        for filename in files:
            file_path = os.path.join(root, filename)
            print(f"[INFO] Processing file: {file_path}")

            with open(file_path, "r", encoding="utf-8") as f:
                for line in f:
                    line = line.strip()
                    if not line:
                        continue
                    
                    try:
                        article = json.loads(line)
                        title = article.get('title', 'Unknown Title')
                        text = article.get('text', '')

                        if text:
                            entities = extract_entities_from_text(text)
                            extracted_data.append({'title': title, 'text': text, 'entities': entities})
                            article_count += 1
                        else:
                            print(f"[WARNING] Skipping empty article: {title}")

                    except json.JSONDecodeError:
                        print(f"[WARNING] Invalid JSON in {file_path}. Skipping.")

                    # Save every BATCH_SIZE articles
                    if article_count % BATCH_SIZE == 0 and article_count > 0:
                        print(f"[INFO] Processed {article_count} articles. Saving to CSV...")
                        save_to_csv(extracted_data)
                        extracted_data = []  # Clear memory

    # Save any remaining data
    if extracted_data:
        print(f"[INFO] Final batch of {len(extracted_data)} articles. Saving to CSV.")
        save_to_csv(extracted_data)

    elapsed_time = time.time() - start_time
    print(f"[INFO] Finished processing {article_count} articles in {elapsed_time:.2f} seconds.")

# Save extracted entities to CSV
def save_to_csv(data):
    """Appends extracted entity data to a CSV file."""
    try:
        df = pd.DataFrame([
            {'title': item['title'], 'text': item['text'], 'entity': ent['text'], 'label': ent['label']}
            for item in data for ent in item['entities']
        ])
        
        df.to_csv(OUTPUT_CSV, mode='a', index=False, encoding='utf-8', header=not os.path.exists(OUTPUT_CSV))
        print(f"[INFO] Saved {len(data)} articles to {OUTPUT_CSV}")

    except Exception as e:
        print(f"[ERROR] Failed to save to CSV: {e}")

# %%
PREPROCESSED_CSV = "processed_data.csv"
OUTPUT_CSV = "extracted_entities.csv"
first_chunk = True
chunk_size = 10000  

for chunk in pd.read_csv(OUTPUT_CSV, chunksize=chunk_size):
    chunk.drop_duplicates(inplace=True)
    chunk.dropna(subset=["text"], inplace=True)

    mode = "w" if first_chunk else "a"  # Write first time, then append
    header = first_chunk  # Write header only once

    chunk.to_csv(PREPROCESSED_CSV, mode=mode, header=header, index=False)
    first_chunk = False  # After first write, switch to append mode
    print(f"[INFO] Saved {len(chunk)} rows")
# Out:
# [INFO] Saved 8025 rows
# [INFO] Saved 8463 rows
# [INFO] Saved 8022 rows
# [INFO] Saved 7840 rows
# [INFO] Saved 7861 rows
# [INFO] Saved 8176 rows
# [INFO] Saved 8074 rows
# [INFO] Saved 8188 rows
# [INFO] Saved 7934 rows
# [INFO] Saved 8164 rows
# [INFO] Saved 8128 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 8153 rows
# [INFO] Saved 8259 rows
# [INFO] Saved 8076 rows
# [INFO] Saved 8154 rows
# [INFO] Saved 8143 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8075 rows
# [INFO] Saved 8168 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 8277 rows
# [INFO] Saved 8261 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 7913 rows
# [INFO] Saved 8186 rows
# [INFO] Saved 8347 rows
# [INFO] Saved 8087 rows
# [INFO] Saved 8069 rows
# [INFO] Saved 8187 rows
# [INFO] Saved 8286 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 7963 rows
# [INFO] Saved 7737 rows
# [INFO] Saved 8279 rows
# [INFO] Saved 8359 rows
# [INFO] Saved 8111 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8165 rows
# [INFO] Saved 8376 rows
# [INFO] Saved 8206 rows
# [INFO] Saved 8016 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 8067 rows
# [INFO] Saved 8062 rows
# [INFO] Saved 8047 rows
# [INFO] Saved 8035 rows
# [INFO] Saved 7923 rows
# [INFO] Saved 7984 rows
# [INFO] Saved 8072 rows
# [INFO] Saved 7739 rows
# [INFO] Saved 7488 rows
# [INFO] Saved 8139 rows
# [INFO] Saved 8088 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 8324 rows
# [INFO] Saved 8341 rows
# [INFO] Saved 8037 rows
# [INFO] Saved 8419 rows
# [INFO] Saved 8524 rows
# [INFO] Saved 8096 rows
# [INFO] Saved 8439 rows
# [INFO] Saved 8519 rows
# [INFO] Saved 8531 rows
# [INFO] Saved 8217 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 8210 rows
# [INFO] Saved 8565 rows
# [INFO] Saved 8129 rows
# [INFO] Saved 8169 rows
# [INFO] Saved 8463 rows
# [INFO] Saved 7966 rows
# [INFO] Saved 8312 rows
# [INFO] Saved 8309 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8446 rows
# [INFO] Saved 8125 rows
# [INFO] Saved 8217 rows
# [INFO] Saved 7919 rows
# [INFO] Saved 8165 rows
# [INFO] Saved 8244 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 8257 rows
# [INFO] Saved 8351 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8028 rows
# [INFO] Saved 8192 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 7755 rows
# [INFO] Saved 7843 rows
# [INFO] Saved 8221 rows
# [INFO] Saved 8193 rows
# [INFO] Saved 8348 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8188 rows
# [INFO] Saved 8123 rows
# [INFO] Saved 8058 rows
# [INFO] Saved 8309 rows
# [INFO] Saved 8556 rows
# [INFO] Saved 8234 rows
# [INFO] Saved 8083 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 8487 rows
# [INFO] Saved 8098 rows
# [INFO] Saved 8552 rows
# [INFO] Saved 8186 rows
# [INFO] Saved 8344 rows
# [INFO] Saved 8532 rows
# [INFO] Saved 8441 rows
# [INFO] Saved 7992 rows
# [INFO] Saved 8246 rows
# [INFO] Saved 8136 rows
# [INFO] Saved 8340 rows
# [INFO] Saved 8177 rows
# [INFO] Saved 8321 rows
# [INFO] Saved 8382 rows
# [INFO] Saved 8301 rows
# [INFO] Saved 8486 rows
# [INFO] Saved 8613 rows
# [INFO] Saved 8735 rows
# [INFO] Saved 8416 rows
# [INFO] Saved 8158 rows
# [INFO] Saved 7943 rows
# [INFO] Saved 8247 rows
# [INFO] Saved 7681 rows
# [INFO] Saved 8219 rows
# [INFO] Saved 8587 rows
# [INFO] Saved 8024 rows
# [INFO] Saved 8221 rows
# [INFO] Saved 8126 rows
# [INFO] Saved 8423 rows
# [INFO] Saved 8263 rows
# [INFO] Saved 8245 rows
# [INFO] Saved 8237 rows
# [INFO] Saved 8054 rows
# [INFO] Saved 7963 rows
# [INFO] Saved 8357 rows
# [INFO] Saved 8481 rows
# [INFO] Saved 8413 rows
# [INFO] Saved 7538 rows
# [INFO] Saved 7935 rows
# [INFO] Saved 8403 rows
# [INFO] Saved 8419 rows
# [INFO] Saved 8277 rows
# [INFO] Saved 8242 rows
# [INFO] Saved 8332 rows
# [INFO] Saved 8317 rows
# [INFO] Saved 8063 rows
# [INFO] Saved 7122 rows
# [INFO] Saved 8111 rows
# [INFO] Saved 8140 rows
# [INFO] Saved 8183 rows
# [INFO] Saved 8103 rows
# [INFO] Saved 7163 rows
# [INFO] Saved 6976 rows
# [INFO] Saved 8200 rows
# [INFO] Saved 7984 rows
# [INFO] Saved 7691 rows
# [INFO] Saved 7723 rows
# [INFO] Saved 7919 rows
# [INFO] Saved 7543 rows
# [INFO] Saved 7906 rows
# [INFO] Saved 8189 rows
# [INFO] Saved 8035 rows
# [INFO] Saved 8072 rows
# [INFO] Saved 7902 rows
# [INFO] Saved 7832 rows
# [INFO] Saved 7853 rows
# [INFO] Saved 7724 rows
# [INFO] Saved 8350 rows
# [INFO] Saved 8477 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8161 rows
# [INFO] Saved 8031 rows
# [INFO] Saved 7968 rows
# [INFO] Saved 8234 rows
# [INFO] Saved 8403 rows
# [INFO] Saved 8130 rows
# [INFO] Saved 8173 rows
# [INFO] Saved 7888 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8345 rows
# [INFO] Saved 8066 rows
# [INFO] Saved 8274 rows
# [INFO] Saved 7995 rows
# [INFO] Saved 8061 rows
# [INFO] Saved 8185 rows
# [INFO] Saved 8386 rows
# [INFO] Saved 8122 rows
# [INFO] Saved 7944 rows
# [INFO] Saved 7882 rows
# [INFO] Saved 8129 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8015 rows
# [INFO] Saved 7968 rows
# [INFO] Saved 8284 rows
# [INFO] Saved 7872 rows
# [INFO] Saved 7863 rows
# [INFO] Saved 7541 rows
# [INFO] Saved 7404 rows
# [INFO] Saved 7744 rows
# [INFO] Saved 7973 rows
# [INFO] Saved 8225 rows
# [INFO] Saved 8293 rows
# [INFO] Saved 8317 rows
# [INFO] Saved 8173 rows
# [INFO] Saved 8193 rows
# [INFO] Saved 7971 rows
# [INFO] Saved 8422 rows
# [INFO] Saved 8088 rows
# [INFO] Saved 7988 rows
# [INFO] Saved 7823 rows
# [INFO] Saved 7956 rows
# [INFO] Saved 8280 rows
# [INFO] Saved 7887 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 7964 rows
# [INFO] Saved 7786 rows
# [INFO] Saved 7815 rows
# [INFO] Saved 7793 rows
# [INFO] Saved 8160 rows
# [INFO] Saved 8222 rows
# [INFO] Saved 8183 rows
# [INFO] Saved 7902 rows
# [INFO] Saved 7836 rows
# [INFO] Saved 8072 rows
# [INFO] Saved 8036 rows
# [INFO] Saved 8295 rows
# [INFO] Saved 8257 rows
# [INFO] Saved 7892 rows
# [INFO] Saved 8225 rows
# [INFO] Saved 7714 rows
# [INFO] Saved 8198 rows
# [INFO] Saved 7938 rows
# [INFO] Saved 8257 rows
# [INFO] Saved 8223 rows
# [INFO] Saved 8255 rows
# [INFO] Saved 7978 rows
# [INFO] Saved 6833 rows
# [INFO] Saved 7902 rows
# [INFO] Saved 8294 rows
# [INFO] Saved 8160 rows
# [INFO] Saved 8508 rows
# [INFO] Saved 8386 rows
# [INFO] Saved 7998 rows
# [INFO] Saved 7844 rows
# [INFO] Saved 7801 rows
# [INFO] Saved 7459 rows
# [INFO] Saved 7707 rows
# [INFO] Saved 7578 rows
# [INFO] Saved 7625 rows
# [INFO] Saved 7834 rows
# [INFO] Saved 7594 rows
# [INFO] Saved 8060 rows
# [INFO] Saved 8196 rows
# [INFO] Saved 8006 rows
# [INFO] Saved 7982 rows
# [INFO] Saved 7918 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 8063 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 7726 rows
# [INFO] Saved 7812 rows
# [INFO] Saved 8021 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 8283 rows
# [INFO] Saved 9124 rows
# [INFO] Saved 7783 rows
# [INFO] Saved 8643 rows
# [INFO] Saved 7997 rows
# [INFO] Saved 8394 rows
# [INFO] Saved 7930 rows
# [INFO] Saved 8733 rows
# [INFO] Saved 8865 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8821 rows
# [INFO] Saved 8098 rows
# [INFO] Saved 8278 rows
# [INFO] Saved 8608 rows
# [INFO] Saved 8715 rows
# [INFO] Saved 8617 rows
# [INFO] Saved 8153 rows
# [INFO] Saved 8697 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 8548 rows
# [INFO] Saved 7599 rows
# [INFO] Saved 8066 rows
# [INFO] Saved 7791 rows
# [INFO] Saved 7952 rows
# [INFO] Saved 8331 rows
# [INFO] Saved 8144 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8163 rows
# [INFO] Saved 8092 rows
# [INFO] Saved 8132 rows
# [INFO] Saved 7834 rows
# [INFO] Saved 8461 rows
# [INFO] Saved 8001 rows
# [INFO] Saved 8031 rows
# [INFO] Saved 8026 rows
# [INFO] Saved 7727 rows
# [INFO] Saved 8133 rows
# [INFO] Saved 7763 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8102 rows
# [INFO] Saved 8360 rows
# [INFO] Saved 8170 rows
# [INFO] Saved 8011 rows
# [INFO] Saved 8233 rows
# [INFO] Saved 8457 rows
# [INFO] Saved 8300 rows
# [INFO] Saved 8178 rows
# [INFO] Saved 8483 rows
# [INFO] Saved 7958 rows
# [INFO] Saved 8146 rows
# [INFO] Saved 7973 rows
# [INFO] Saved 8005 rows
# [INFO] Saved 7583 rows
# [INFO] Saved 8228 rows
# [INFO] Saved 8320 rows
# [INFO] Saved 8131 rows
# [INFO] Saved 8016 rows
# [INFO] Saved 8389 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8189 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8200 rows
# [INFO] Saved 8157 rows
# [INFO] Saved 7772 rows
# [INFO] Saved 7729 rows
# [INFO] Saved 7448 rows
# [INFO] Saved 8073 rows
# [INFO] Saved 8340 rows
# [INFO] Saved 7925 rows
# [INFO] Saved 8206 rows
# [INFO] Saved 7996 rows
# [INFO] Saved 7846 rows
# [INFO] Saved 8048 rows
# [INFO] Saved 7900 rows
# [INFO] Saved 8157 rows
# [INFO] Saved 7964 rows
# [INFO] Saved 8139 rows
# [INFO] Saved 7768 rows
# [INFO] Saved 8063 rows
# [INFO] Saved 7987 rows
# [INFO] Saved 7854 rows
# [INFO] Saved 7334 rows
# [INFO] Saved 7561 rows
# [INFO] Saved 7663 rows
# [INFO] Saved 7719 rows
# [INFO] Saved 7723 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 7955 rows
# [INFO] Saved 7797 rows
# [INFO] Saved 7858 rows
# [INFO] Saved 7867 rows
# [INFO] Saved 7788 rows
# [INFO] Saved 7619 rows
# [INFO] Saved 8037 rows
# [INFO] Saved 8202 rows
# [INFO] Saved 8175 rows
# [INFO] Saved 8625 rows
# [INFO] Saved 8068 rows
# [INFO] Saved 8300 rows
# [INFO] Saved 8312 rows
# [INFO] Saved 8157 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 7927 rows
# [INFO] Saved 7777 rows
# [INFO] Saved 8358 rows
# [INFO] Saved 8359 rows
# [INFO] Saved 8487 rows
# [INFO] Saved 8314 rows
# [INFO] Saved 7589 rows
# [INFO] Saved 7758 rows
# [INFO] Saved 8251 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 7827 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8260 rows
# [INFO] Saved 8342 rows
# [INFO] Saved 8318 rows
# [INFO] Saved 8260 rows
# [INFO] Saved 8083 rows
# [INFO] Saved 7756 rows
# [INFO] Saved 8122 rows
# [INFO] Saved 8041 rows
# [INFO] Saved 8236 rows
# [INFO] Saved 8189 rows
# [INFO] Saved 8203 rows
# [INFO] Saved 7972 rows
# [INFO] Saved 8458 rows
# [INFO] Saved 7839 rows
# [INFO] Saved 8267 rows
# [INFO] Saved 8358 rows
# [INFO] Saved 8386 rows
# [INFO] Saved 8805 rows
# [INFO] Saved 9050 rows
# [INFO] Saved 8643 rows
# [INFO] Saved 9105 rows
# [INFO] Saved 8428 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 8359 rows
# [INFO] Saved 8939 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8233 rows
# [INFO] Saved 7534 rows
# [INFO] Saved 8382 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 8208 rows
# [INFO] Saved 8227 rows
# [INFO] Saved 7951 rows
# [INFO] Saved 8011 rows
# [INFO] Saved 8450 rows
# [INFO] Saved 8305 rows
# [INFO] Saved 8288 rows
# [INFO] Saved 8306 rows
# [INFO] Saved 8357 rows
# [INFO] Saved 8563 rows
# [INFO] Saved 8322 rows
# [INFO] Saved 8258 rows
# [INFO] Saved 8332 rows
# [INFO] Saved 8233 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8295 rows
# [INFO] Saved 8067 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8348 rows
# [INFO] Saved 8025 rows
# [INFO] Saved 8272 rows
# [INFO] Saved 8608 rows
# [INFO] Saved 8666 rows
# [INFO] Saved 8045 rows
# [INFO] Saved 8544 rows
# [INFO] Saved 8307 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 7978 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 7887 rows
# [INFO] Saved 8092 rows
# [INFO] Saved 8017 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 7889 rows
# [INFO] Saved 7953 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 7928 rows
# [INFO] Saved 7999 rows
# [INFO] Saved 7767 rows
# [INFO] Saved 7649 rows
# [INFO] Saved 7966 rows
# [INFO] Saved 7870 rows
# [INFO] Saved 8005 rows
# [INFO] Saved 7877 rows
# [INFO] Saved 7744 rows
# [INFO] Saved 7986 rows
# [INFO] Saved 7718 rows
# [INFO] Saved 7620 rows
# [INFO] Saved 8131 rows
# [INFO] Saved 7729 rows
# [INFO] Saved 7943 rows
# [INFO] Saved 7354 rows
# [INFO] Saved 7942 rows
# [INFO] Saved 7852 rows
# [INFO] Saved 7400 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 7527 rows
# [INFO] Saved 8008 rows
# [INFO] Saved 7710 rows
# [INFO] Saved 7807 rows
# [INFO] Saved 7572 rows
# [INFO] Saved 7925 rows
# [INFO] Saved 8101 rows
# [INFO] Saved 7870 rows
# [INFO] Saved 7668 rows
# [INFO] Saved 7715 rows
# [INFO] Saved 7949 rows
# [INFO] Saved 7658 rows
# [INFO] Saved 7932 rows
# [INFO] Saved 7927 rows
# [INFO] Saved 7988 rows
# [INFO] Saved 7591 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 7873 rows
# [INFO] Saved 7943 rows
# [INFO] Saved 8103 rows
# [INFO] Saved 8105 rows
# [INFO] Saved 7895 rows
# [INFO] Saved 8186 rows
# [INFO] Saved 8515 rows
# [INFO] Saved 8000 rows
# [INFO] Saved 7990 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8442 rows
# [INFO] Saved 8288 rows
# [INFO] Saved 8166 rows
# [INFO] Saved 8399 rows
# [INFO] Saved 8438 rows
# [INFO] Saved 8607 rows
# [INFO] Saved 8112 rows
# [INFO] Saved 8282 rows
# [INFO] Saved 7630 rows
# [INFO] Saved 7851 rows
# [INFO] Saved 8014 rows
# [INFO] Saved 7804 rows
# [INFO] Saved 7577 rows
# [INFO] Saved 7735 rows
# [INFO] Saved 8075 rows
# [INFO] Saved 7783 rows
# [INFO] Saved 7933 rows
# [INFO] Saved 7805 rows
# [INFO] Saved 7733 rows
# [INFO] Saved 8097 rows
# [INFO] Saved 7748 rows
# [INFO] Saved 7676 rows
# [INFO] Saved 7920 rows
# [INFO] Saved 7700 rows
# [INFO] Saved 8017 rows
# [INFO] Saved 8367 rows
# [INFO] Saved 7993 rows
# [INFO] Saved 8385 rows
# [INFO] Saved 7922 rows
# [INFO] Saved 8215 rows
# [INFO] Saved 8091 rows
# [INFO] Saved 8245 rows
# [INFO] Saved 8260 rows
# [INFO] Saved 8300 rows
# [INFO] Saved 7337 rows
# [INFO] Saved 8133 rows
# [INFO] Saved 8126 rows
# [INFO] Saved 8182 rows
# [INFO] Saved 7982 rows
# [INFO] Saved 8060 rows
# [INFO] Saved 7511 rows
# [INFO] Saved 8180 rows
# [INFO] Saved 8016 rows
# [INFO] Saved 7916 rows
# [INFO] Saved 8040 rows
# [INFO] Saved 8055 rows
# [INFO] Saved 7874 rows
# [INFO] Saved 7706 rows
# [INFO] Saved 7720 rows
# [INFO] Saved 7486 rows
# [INFO] Saved 7996 rows
# [INFO] Saved 7918 rows
# [INFO] Saved 8070 rows
# [INFO] Saved 7922 rows
# [INFO] Saved 7956 rows
# [INFO] Saved 7366 rows
# [INFO] Saved 7842 rows
# [INFO] Saved 7860 rows
# [INFO] Saved 7768 rows
# [INFO] Saved 7890 rows
# [INFO] Saved 7756 rows
# [INFO] Saved 7921 rows
# [INFO] Saved 7670 rows
# [INFO] Saved 7937 rows
# [INFO] Saved 8140 rows
# [INFO] Saved 7882 rows
# [INFO] Saved 7672 rows
# [INFO] Saved 8030 rows
# [INFO] Saved 8147 rows
# [INFO] Saved 8044 rows
# [INFO] Saved 7938 rows
# [INFO] Saved 7773 rows
# [INFO] Saved 7993 rows
# [INFO] Saved 7719 rows
# [INFO] Saved 7946 rows
# [INFO] Saved 8254 rows
# [INFO] Saved 7379 rows
# [INFO] Saved 8099 rows
# [INFO] Saved 8086 rows
# [INFO] Saved 7135 rows
# [INFO] Saved 7697 rows
# [INFO] Saved 7755 rows
# [INFO] Saved 7701 rows
# [INFO] Saved 7868 rows
# [INFO] Saved 8227 rows
# [INFO] Saved 8223 rows
# [INFO] Saved 8134 rows
# [INFO] Saved 8001 rows
# [INFO] Saved 7965 rows
# [INFO] Saved 7964 rows
# [INFO] Saved 8064 rows
# [INFO] Saved 7511 rows
# [INFO] Saved 7588 rows
# [INFO] Saved 7813 rows
# [INFO] Saved 7933 rows
# [INFO] Saved 7386 rows
# [INFO] Saved 8197 rows
# [INFO] Saved 7991 rows
# [INFO] Saved 8063 rows
# [INFO] Saved 8262 rows
# [INFO] Saved 7872 rows
# [INFO] Saved 8196 rows
# [INFO] Saved 7984 rows
# [INFO] Saved 7962 rows
# [INFO] Saved 8184 rows
# [INFO] Saved 7845 rows
# [INFO] Saved 7533 rows
# [INFO] Saved 8284 rows
# [INFO] Saved 7434 rows
# [INFO] Saved 8134 rows
# [INFO] Saved 7771 rows
# [INFO] Saved 8037 rows
# [INFO] Saved 7962 rows
# [INFO] Saved 7980 rows
# [INFO] Saved 7879 rows
# [INFO] Saved 8272 rows
# [INFO] Saved 7514 rows
# [INFO] Saved 7816 rows
# [INFO] Saved 7830 rows
# [INFO] Saved 7853 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 7915 rows
# [INFO] Saved 8196 rows
# [INFO] Saved 7876 rows
# [INFO] Saved 7715 rows
# [INFO] Saved 7843 rows
# [INFO] Saved 7839 rows
# [INFO] Saved 7849 rows
# [INFO] Saved 7604 rows
# [INFO] Saved 7493 rows
# [INFO] Saved 7575 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 7993 rows
# [INFO] Saved 7789 rows
# [INFO] Saved 7997 rows
# [INFO] Saved 8136 rows
# [INFO] Saved 8195 rows
# [INFO] Saved 7742 rows
# [INFO] Saved 8302 rows
# [INFO] Saved 7906 rows
# [INFO] Saved 7934 rows
# [INFO] Saved 7939 rows
# [INFO] Saved 7845 rows
# [INFO] Saved 8010 rows
# [INFO] Saved 7887 rows
# [INFO] Saved 8001 rows
# [INFO] Saved 8051 rows
# [INFO] Saved 7884 rows
# [INFO] Saved 7957 rows
# [INFO] Saved 8035 rows
# [INFO] Saved 7618 rows
# [INFO] Saved 8196 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 7826 rows
# [INFO] Saved 7949 rows
# [INFO] Saved 8262 rows
# [INFO] Saved 8303 rows
# [INFO] Saved 8200 rows
# [INFO] Saved 8052 rows
# [INFO] Saved 8314 rows
# [INFO] Saved 8101 rows
# [INFO] Saved 8621 rows
# [INFO] Saved 8357 rows
# [INFO] Saved 8157 rows
# [INFO] Saved 7884 rows
# [INFO] Saved 8442 rows
# [INFO] Saved 8206 rows
# [INFO] Saved 8353 rows
# [INFO] Saved 8261 rows
# [INFO] Saved 7862 rows
# [INFO] Saved 8063 rows
# [INFO] Saved 8031 rows
# [INFO] Saved 7950 rows
# [INFO] Saved 8079 rows
# [INFO] Saved 7929 rows
# [INFO] Saved 7377 rows
# [INFO] Saved 7714 rows
# [INFO] Saved 7866 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 7869 rows
# [INFO] Saved 7858 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8111 rows
# [INFO] Saved 7690 rows
# [INFO] Saved 7604 rows
# [INFO] Saved 8011 rows
# [INFO] Saved 7589 rows
# [INFO] Saved 7947 rows
# [INFO] Saved 7654 rows
# [INFO] Saved 7931 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8279 rows
# [INFO] Saved 8538 rows
# [INFO] Saved 7713 rows
# [INFO] Saved 7669 rows
# [INFO] Saved 7789 rows
# [INFO] Saved 7847 rows
# [INFO] Saved 8232 rows
# [INFO] Saved 7955 rows
# [INFO] Saved 7934 rows
# [INFO] Saved 7774 rows
# [INFO] Saved 8061 rows
# [INFO] Saved 7822 rows
# [INFO] Saved 7852 rows
# [INFO] Saved 8116 rows
# [INFO] Saved 7445 rows
# [INFO] Saved 7910 rows
# [INFO] Saved 7891 rows
# [INFO] Saved 7860 rows
# [INFO] Saved 7815 rows
# [INFO] Saved 7307 rows
# [INFO] Saved 7654 rows
# [INFO] Saved 7888 rows
# [INFO] Saved 7820 rows
# [INFO] Saved 7984 rows
# [INFO] Saved 7542 rows
# [INFO] Saved 7979 rows
# [INFO] Saved 7921 rows
# [INFO] Saved 7578 rows
# [INFO] Saved 7804 rows
# [INFO] Saved 7483 rows
# [INFO] Saved 7914 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 7638 rows
# [INFO] Saved 8001 rows
# [INFO] Saved 8041 rows
# [INFO] Saved 7806 rows
# [INFO] Saved 8051 rows
# [INFO] Saved 7807 rows
# [INFO] Saved 8053 rows
# [INFO] Saved 8103 rows
# [INFO] Saved 8026 rows
# [INFO] Saved 8078 rows
# [INFO] Saved 8355 rows
# [INFO] Saved 6063 rows
# [INFO] Saved 7649 rows
# [INFO] Saved 7940 rows
# [INFO] Saved 8062 rows
# [INFO] Saved 8249 rows
# [INFO] Saved 8038 rows
# [INFO] Saved 7558 rows
# [INFO] Saved 7985 rows
# [INFO] Saved 7973 rows
# [INFO] Saved 7888 rows
# [INFO] Saved 7923 rows
# [INFO] Saved 8216 rows
# [INFO] Saved 7862 rows
# [INFO] Saved 8073 rows
# [INFO] Saved 8058 rows
# [INFO] Saved 8119 rows
# [INFO] Saved 8383 rows
# [INFO] Saved 9104 rows
# [INFO] Saved 8353 rows
# [INFO] Saved 8536 rows
# [INFO] Saved 8307 rows
# [INFO] Saved 8250 rows
# [INFO] Saved 8656 rows
# [INFO] Saved 8520 rows
# [INFO] Saved 8479 rows
# [INFO] Saved 8468 rows
# [INFO] Saved 8417 rows
# [INFO] Saved 8472 rows
# [INFO] Saved 8571 rows
# [INFO] Saved 8551 rows
# [INFO] Saved 8209 rows
# [INFO] Saved 7747 rows
# [INFO] Saved 8374 rows
# [INFO] Saved 7872 rows
# [INFO] Saved 7831 rows
# [INFO] Saved 8304 rows
# [INFO] Saved 8183 rows
# [INFO] Saved 8254 rows
# [INFO] Saved 7404 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 8439 rows
# [INFO] Saved 8005 rows
# [INFO] Saved 8402 rows
# [INFO] Saved 8076 rows
# [INFO] Saved 8115 rows
# [INFO] Saved 7974 rows
# [INFO] Saved 7734 rows
# [INFO] Saved 7911 rows
# [INFO] Saved 8207 rows
# [INFO] Saved 8737 rows
# [INFO] Saved 8597 rows
# [INFO] Saved 8537 rows
# [INFO] Saved 8834 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 9236 rows
# [INFO] Saved 7987 rows
# [INFO] Saved 7758 rows
# [INFO] Saved 8886 rows
# [INFO] Saved 8395 rows
# [INFO] Saved 8707 rows
# [INFO] Saved 8787 rows
# [INFO] Saved 8534 rows
# [INFO] Saved 8661 rows
# [INFO] Saved 8534 rows
# [INFO] Saved 8167 rows
# [INFO] Saved 8630 rows
# [INFO] Saved 8663 rows
# [INFO] Saved 8707 rows
# [INFO] Saved 8350 rows
# [INFO] Saved 8012 rows
# [INFO] Saved 8925 rows
# [INFO] Saved 8539 rows
# [INFO] Saved 8089 rows
# [INFO] Saved 8642 rows
# [INFO] Saved 9367 rows
# [INFO] Saved 8745 rows
# [INFO] Saved 8361 rows
# [INFO] Saved 8284 rows
# [INFO] Saved 7985 rows
# [INFO] Saved 8485 rows
# [INFO] Saved 8816 rows
# [INFO] Saved 8432 rows
# [INFO] Saved 8702 rows
# [INFO] Saved 8272 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8340 rows
# [INFO] Saved 8564 rows
# [INFO] Saved 8437 rows
# [INFO] Saved 8094 rows
# [INFO] Saved 8235 rows
# [INFO] Saved 8723 rows
# [INFO] Saved 8095 rows
# [INFO] Saved 8236 rows
# [INFO] Saved 8354 rows
# [INFO] Saved 8522 rows
# [INFO] Saved 8633 rows
# [INFO] Saved 8317 rows
# [INFO] Saved 8830 rows
# [INFO] Saved 8668 rows
# [INFO] Saved 8502 rows
# [INFO] Saved 8729 rows
# [INFO] Saved 7931 rows
# [INFO] Saved 7612 rows
# [INFO] Saved 8696 rows
# [INFO] Saved 8983 rows
# [INFO] Saved 9292 rows
# [INFO] Saved 8126 rows
# [INFO] Saved 8189 rows
# [INFO] Saved 9160 rows
# [INFO] Saved 8948 rows
# [INFO] Saved 8610 rows
# [INFO] Saved 9007 rows
# [INFO] Saved 8834 rows
# [INFO] Saved 8480 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 8487 rows
# [INFO] Saved 7944 rows
# [INFO] Saved 7873 rows
# [INFO] Saved 7553 rows
# [INFO] Saved 8047 rows
# [INFO] Saved 8579 rows
# [INFO] Saved 8976 rows
# [INFO] Saved 8721 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8568 rows
# [INFO] Saved 8759 rows
# [INFO] Saved 8669 rows
# [INFO] Saved 8172 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 8715 rows
# [INFO] Saved 9133 rows
# [INFO] Saved 8208 rows
# [INFO] Saved 8505 rows
# [INFO] Saved 8136 rows
# [INFO] Saved 7240 rows
# [INFO] Saved 8677 rows
# [INFO] Saved 8036 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 9040 rows
# [INFO] Saved 8930 rows
# [INFO] Saved 8377 rows
# [INFO] Saved 8405 rows
# [INFO] Saved 8022 rows
# [INFO] Saved 8309 rows
# [INFO] Saved 8671 rows
# [INFO] Saved 8667 rows
# [INFO] Saved 8477 rows
# [INFO] Saved 7770 rows
# [INFO] Saved 8553 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8696 rows
# [INFO] Saved 8139 rows
# [INFO] Saved 7560 rows
# [INFO] Saved 8061 rows
# [INFO] Saved 8042 rows
# [INFO] Saved 8140 rows
# [INFO] Saved 8388 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 7861 rows
# [INFO] Saved 8009 rows
# [INFO] Saved 8201 rows
# [INFO] Saved 7890 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 8114 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8416 rows
# [INFO] Saved 8162 rows
# [INFO] Saved 8033 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8267 rows
# [INFO] Saved 7985 rows
# [INFO] Saved 7974 rows
# [INFO] Saved 7482 rows
# [INFO] Saved 8319 rows
# [INFO] Saved 7956 rows
# [INFO] Saved 7983 rows
# [INFO] Saved 8132 rows
# [INFO] Saved 7829 rows
# [INFO] Saved 7772 rows
# [INFO] Saved 7102 rows
# [INFO] Saved 8142 rows
# [INFO] Saved 8293 rows
# [INFO] Saved 8291 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8418 rows
# [INFO] Saved 7822 rows
# [INFO] Saved 8172 rows
# [INFO] Saved 8505 rows
# [INFO] Saved 8276 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8236 rows
# [INFO] Saved 8294 rows
# [INFO] Saved 8351 rows
# [INFO] Saved 8132 rows
# [INFO] Saved 8250 rows
# [INFO] Saved 8492 rows
# [INFO] Saved 8424 rows
# [INFO] Saved 8188 rows
# [INFO] Saved 8462 rows
# [INFO] Saved 8648 rows
# [INFO] Saved 8235 rows
# [INFO] Saved 8794 rows
# [INFO] Saved 8484 rows
# [INFO] Saved 8795 rows
# [INFO] Saved 8767 rows
# [INFO] Saved 9007 rows
# [INFO] Saved 8990 rows
# [INFO] Saved 9864 rows
# [INFO] Saved 9471 rows
# [INFO] Saved 8534 rows
# [INFO] Saved 9288 rows
# [INFO] Saved 8776 rows
# [INFO] Saved 8664 rows
# [INFO] Saved 9004 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8857 rows
# [INFO] Saved 9135 rows
# [INFO] Saved 7872 rows
# [INFO] Saved 8588 rows
# [INFO] Saved 8369 rows
# [INFO] Saved 8423 rows
# [INFO] Saved 8070 rows
# [INFO] Saved 8441 rows
# [INFO] Saved 8787 rows
# [INFO] Saved 8579 rows
# [INFO] Saved 7943 rows
# [INFO] Saved 7970 rows
# [INFO] Saved 8522 rows
# [INFO] Saved 7561 rows
# [INFO] Saved 8342 rows
# [INFO] Saved 8407 rows
# [INFO] Saved 8202 rows
# [INFO] Saved 8287 rows
# [INFO] Saved 8127 rows
# [INFO] Saved 8317 rows
# [INFO] Saved 7944 rows
# [INFO] Saved 8131 rows
# [INFO] Saved 8340 rows
# [INFO] Saved 8390 rows
# [INFO] Saved 8415 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8335 rows
# [INFO] Saved 8213 rows
# [INFO] Saved 8200 rows
# [INFO] Saved 8136 rows
# [INFO] Saved 8468 rows
# [INFO] Saved 8015 rows
# [INFO] Saved 8595 rows
# [INFO] Saved 8245 rows
# [INFO] Saved 8320 rows
# [INFO] Saved 8547 rows
# [INFO] Saved 8524 rows
# [INFO] Saved 8334 rows
# [INFO] Saved 8684 rows
# [INFO] Saved 8520 rows
# [INFO] Saved 8284 rows
# [INFO] Saved 8526 rows
# [INFO] Saved 8184 rows
# [INFO] Saved 8294 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 8452 rows
# [INFO] Saved 8124 rows
# [INFO] Saved 7897 rows
# [INFO] Saved 8097 rows
# [INFO] Saved 8477 rows
# [INFO] Saved 8243 rows
# [INFO] Saved 8043 rows
# [INFO] Saved 7829 rows
# [INFO] Saved 8276 rows
# [INFO] Saved 8197 rows
# [INFO] Saved 8194 rows
# [INFO] Saved 8422 rows
# [INFO] Saved 8493 rows
# [INFO] Saved 8074 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8336 rows
# [INFO] Saved 7977 rows
# [INFO] Saved 8280 rows
# [INFO] Saved 7744 rows
# [INFO] Saved 7995 rows
# [INFO] Saved 8389 rows
# [INFO] Saved 8306 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 8553 rows
# [INFO] Saved 8489 rows
# [INFO] Saved 8275 rows
# [INFO] Saved 8855 rows
# [INFO] Saved 9663 rows
# [INFO] Saved 9494 rows
# [INFO] Saved 9017 rows
# [INFO] Saved 9710 rows
# [INFO] Saved 9487 rows
# [INFO] Saved 9435 rows
# [INFO] Saved 9676 rows
# [INFO] Saved 9699 rows
# [INFO] Saved 9719 rows
# [INFO] Saved 9636 rows
# [INFO] Saved 9530 rows
# [INFO] Saved 9759 rows
# [INFO] Saved 9483 rows
# [INFO] Saved 7953 rows
# [INFO] Saved 8485 rows
# [INFO] Saved 8414 rows
# [INFO] Saved 8526 rows
# [INFO] Saved 8855 rows
# [INFO] Saved 8331 rows
# [INFO] Saved 8681 rows
# [INFO] Saved 8589 rows
# [INFO] Saved 8323 rows
# [INFO] Saved 8376 rows
# [INFO] Saved 8381 rows
# [INFO] Saved 8298 rows
# [INFO] Saved 8333 rows
# [INFO] Saved 8295 rows
# [INFO] Saved 8566 rows
# [INFO] Saved 8275 rows
# [INFO] Saved 8399 rows
# [INFO] Saved 8097 rows
# [INFO] Saved 8220 rows
# [INFO] Saved 8282 rows
# [INFO] Saved 8186 rows
# [INFO] Saved 8227 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8339 rows
# [INFO] Saved 8029 rows
# [INFO] Saved 8195 rows
# [INFO] Saved 8262 rows
# [INFO] Saved 8648 rows
# [INFO] Saved 8341 rows
# [INFO] Saved 8352 rows
# [INFO] Saved 8574 rows
# [INFO] Saved 7974 rows
# [INFO] Saved 8321 rows
# [INFO] Saved 8250 rows
# [INFO] Saved 8167 rows
# [INFO] Saved 7833 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 7916 rows
# [INFO] Saved 8337 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 8258 rows
# [INFO] Saved 8376 rows
# [INFO] Saved 8081 rows
# [INFO] Saved 8032 rows
# [INFO] Saved 8099 rows
# [INFO] Saved 8284 rows
# [INFO] Saved 7987 rows
# [INFO] Saved 7933 rows
# [INFO] Saved 8100 rows
# [INFO] Saved 8072 rows
# [INFO] Saved 8035 rows
# [INFO] Saved 8354 rows
# [INFO] Saved 8275 rows
# [INFO] Saved 8069 rows
# [INFO] Saved 8284 rows
# [INFO] Saved 8252 rows
# [INFO] Saved 8101 rows
# [INFO] Saved 8419 rows
# [INFO] Saved 8173 rows
# [INFO] Saved 7929 rows
# [INFO] Saved 8058 rows
# [INFO] Saved 7808 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8025 rows
# [INFO] Saved 8072 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8062 rows
# [INFO] Saved 7878 rows
# [INFO] Saved 8198 rows
# [INFO] Saved 8357 rows
# [INFO] Saved 8159 rows
# [INFO] Saved 7726 rows
# [INFO] Saved 8339 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 8177 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8081 rows
# [INFO] Saved 8504 rows
# [INFO] Saved 8441 rows
# [INFO] Saved 7791 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 8429 rows
# [INFO] Saved 8366 rows
# [INFO] Saved 8307 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 8185 rows
# [INFO] Saved 7994 rows
# [INFO] Saved 8088 rows
# [INFO] Saved 8124 rows
# [INFO] Saved 8525 rows
# [INFO] Saved 8215 rows
# [INFO] Saved 8067 rows
# [INFO] Saved 8281 rows
# [INFO] Saved 8565 rows
# [INFO] Saved 7650 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8212 rows
# [INFO] Saved 8379 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8493 rows
# [INFO] Saved 8179 rows
# [INFO] Saved 8398 rows
# [INFO] Saved 8415 rows
# [INFO] Saved 8673 rows
# [INFO] Saved 8402 rows
# [INFO] Saved 8619 rows
# [INFO] Saved 8662 rows
# [INFO] Saved 8320 rows
# [INFO] Saved 8579 rows
# [INFO] Saved 8881 rows
# [INFO] Saved 9169 rows
# [INFO] Saved 9504 rows
# [INFO] Saved 9298 rows
# [INFO] Saved 8430 rows
# [INFO] Saved 8006 rows
# [INFO] Saved 8390 rows
# [INFO] Saved 8343 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8221 rows
# [INFO] Saved 8324 rows
# [INFO] Saved 8530 rows
# [INFO] Saved 8515 rows
# [INFO] Saved 8006 rows
# [INFO] Saved 7931 rows
# [INFO] Saved 7982 rows
# [INFO] Saved 7976 rows
# [INFO] Saved 7968 rows
# [INFO] Saved 8342 rows
# [INFO] Saved 8324 rows
# [INFO] Saved 8163 rows
# [INFO] Saved 8122 rows
# [INFO] Saved 8242 rows
# [INFO] Saved 8137 rows
# [INFO] Saved 7847 rows
# [INFO] Saved 8249 rows
# [INFO] Saved 8236 rows
# [INFO] Saved 8273 rows
# [INFO] Saved 7706 rows
# [INFO] Saved 7461 rows
# [INFO] Saved 7907 rows
# [INFO] Saved 8333 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 8095 rows
# [INFO] Saved 7890 rows
# [INFO] Saved 8373 rows
# [INFO] Saved 8256 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 8396 rows
# [INFO] Saved 8308 rows
# [INFO] Saved 8149 rows
# [INFO] Saved 8120 rows
# [INFO] Saved 8277 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8279 rows
# [INFO] Saved 8378 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8164 rows
# [INFO] Saved 8075 rows
# [INFO] Saved 8360 rows
# [INFO] Saved 7972 rows
# [INFO] Saved 8271 rows
# [INFO] Saved 8355 rows
# [INFO] Saved 8422 rows
# [INFO] Saved 8585 rows
# [INFO] Saved 8277 rows
# [INFO] Saved 8334 rows
# [INFO] Saved 8159 rows
# [INFO] Saved 8138 rows
# [INFO] Saved 8591 rows
# [INFO] Saved 8352 rows
# [INFO] Saved 8253 rows
# [INFO] Saved 7626 rows
# [INFO] Saved 8468 rows
# [INFO] Saved 8041 rows
# [INFO] Saved 8537 rows
# [INFO] Saved 8378 rows
# [INFO] Saved 8301 rows
# [INFO] Saved 8118 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 7893 rows
# [INFO] Saved 8189 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 8197 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8361 rows
# [INFO] Saved 8261 rows
# [INFO] Saved 8303 rows
# [INFO] Saved 8216 rows
# [INFO] Saved 7742 rows
# [INFO] Saved 7039 rows
# [INFO] Saved 8342 rows
# [INFO] Saved 8363 rows
# [INFO] Saved 8390 rows
# [INFO] Saved 8443 rows
# [INFO] Saved 8207 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8559 rows
# [INFO] Saved 8073 rows
# [INFO] Saved 7794 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 8518 rows
# [INFO] Saved 8278 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 8283 rows
# [INFO] Saved 8301 rows
# [INFO] Saved 8465 rows
# [INFO] Saved 8617 rows
# [INFO] Saved 8673 rows
# [INFO] Saved 7696 rows
# [INFO] Saved 8467 rows
# [INFO] Saved 8247 rows
# [INFO] Saved 8420 rows
# [INFO] Saved 8397 rows
# [INFO] Saved 8049 rows
# [INFO] Saved 8345 rows
# [INFO] Saved 8629 rows
# [INFO] Saved 7887 rows
# [INFO] Saved 8505 rows
# [INFO] Saved 7929 rows
# [INFO] Saved 8566 rows
# [INFO] Saved 8618 rows
# [INFO] Saved 7758 rows
# [INFO] Saved 8042 rows
# [INFO] Saved 8383 rows
# [INFO] Saved 7859 rows
# [INFO] Saved 8513 rows
# [INFO] Saved 8235 rows
# [INFO] Saved 8158 rows
# [INFO] Saved 8258 rows
# [INFO] Saved 8179 rows
# [INFO] Saved 8281 rows
# [INFO] Saved 8188 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8022 rows
# [INFO] Saved 8299 rows
# [INFO] Saved 8380 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8325 rows
# [INFO] Saved 7729 rows
# [INFO] Saved 8067 rows
# [INFO] Saved 7921 rows
# [INFO] Saved 8112 rows
# [INFO] Saved 8279 rows
# [INFO] Saved 8259 rows
# [INFO] Saved 8069 rows
# [INFO] Saved 8029 rows
# [INFO] Saved 7836 rows
# [INFO] Saved 8272 rows
# [INFO] Saved 8157 rows
# [INFO] Saved 8157 rows
# [INFO] Saved 7500 rows
# [INFO] Saved 7928 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 7931 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 7776 rows
# [INFO] Saved 8206 rows
# [INFO] Saved 8515 rows
# [INFO] Saved 8225 rows
# [INFO] Saved 8271 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 8060 rows
# [INFO] Saved 8328 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 8247 rows
# [INFO] Saved 8367 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8065 rows
# [INFO] Saved 8395 rows
# [INFO] Saved 8224 rows
# [INFO] Saved 8615 rows
# [INFO] Saved 8160 rows
# [INFO] Saved 8461 rows
# [INFO] Saved 7580 rows
# [INFO] Saved 8183 rows
# [INFO] Saved 8012 rows
# [INFO] Saved 8152 rows
# [INFO] Saved 8125 rows
# [INFO] Saved 7900 rows
# [INFO] Saved 8159 rows
# [INFO] Saved 8654 rows
# [INFO] Saved 8401 rows
# [INFO] Saved 7905 rows
# [INFO] Saved 8473 rows
# [INFO] Saved 7734 rows
# [INFO] Saved 7906 rows
# [INFO] Saved 8278 rows
# [INFO] Saved 8281 rows
# [INFO] Saved 7657 rows
# [INFO] Saved 7613 rows
# [INFO] Saved 8193 rows
# [INFO] Saved 7682 rows
# [INFO] Saved 8195 rows
# [INFO] Saved 7685 rows
# [INFO] Saved 8293 rows
# [INFO] Saved 7998 rows
# [INFO] Saved 7903 rows
# [INFO] Saved 8057 rows
# [INFO] Saved 8253 rows
# [INFO] Saved 8455 rows
# [INFO] Saved 8345 rows
# [INFO] Saved 8020 rows
# [INFO] Saved 7750 rows
# [INFO] Saved 7907 rows
# [INFO] Saved 8276 rows
# [INFO] Saved 7994 rows
# [INFO] Saved 8243 rows
# [INFO] Saved 8401 rows
# [INFO] Saved 8332 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8179 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 8033 rows
# [INFO] Saved 8124 rows
# [INFO] Saved 8035 rows
# [INFO] Saved 8261 rows
# [INFO] Saved 8185 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 8302 rows
# [INFO] Saved 7952 rows
# [INFO] Saved 8263 rows
# [INFO] Saved 7932 rows
# [INFO] Saved 7744 rows
# [INFO] Saved 8085 rows
# [INFO] Saved 8147 rows
# [INFO] Saved 8067 rows
# [INFO] Saved 8000 rows
# [INFO] Saved 7835 rows
# [INFO] Saved 7618 rows
# [INFO] Saved 7616 rows
# [INFO] Saved 8079 rows
# [INFO] Saved 7753 rows
# [INFO] Saved 7766 rows
# [INFO] Saved 7984 rows
# [INFO] Saved 8346 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 8061 rows
# [INFO] Saved 7621 rows
# [INFO] Saved 8115 rows
# [INFO] Saved 7852 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8246 rows
# [INFO] Saved 8015 rows
# [INFO] Saved 7735 rows
# [INFO] Saved 7815 rows
# [INFO] Saved 8178 rows
# [INFO] Saved 7838 rows
# [INFO] Saved 8025 rows
# [INFO] Saved 8029 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 8163 rows
# [INFO] Saved 8416 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 8578 rows
# [INFO] Saved 7896 rows
# [INFO] Saved 8506 rows
# [INFO] Saved 8165 rows
# [INFO] Saved 7731 rows
# [INFO] Saved 7901 rows
# [INFO] Saved 7858 rows
# [INFO] Saved 8028 rows
# [INFO] Saved 8069 rows
# [INFO] Saved 8001 rows
# [INFO] Saved 8071 rows
# [INFO] Saved 7870 rows
# [INFO] Saved 8051 rows
# [INFO] Saved 8079 rows
# [INFO] Saved 8319 rows
# [INFO] Saved 8262 rows
# [INFO] Saved 8361 rows
# [INFO] Saved 8073 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8340 rows
# [INFO] Saved 8000 rows
# [INFO] Saved 8212 rows
# [INFO] Saved 7971 rows
# [INFO] Saved 7804 rows
# [INFO] Saved 7830 rows
# [INFO] Saved 7955 rows
# [INFO] Saved 7920 rows
# [INFO] Saved 8259 rows
# [INFO] Saved 8176 rows
# [INFO] Saved 8515 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 8358 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 8361 rows
# [INFO] Saved 8116 rows
# [INFO] Saved 8492 rows
# [INFO] Saved 8317 rows
# [INFO] Saved 8224 rows
# [INFO] Saved 8537 rows
# [INFO] Saved 8483 rows
# [INFO] Saved 8194 rows
# [INFO] Saved 8315 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 7850 rows
# [INFO] Saved 8259 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 8014 rows
# [INFO] Saved 8091 rows
# [INFO] Saved 7736 rows
# [INFO] Saved 8198 rows
# [INFO] Saved 8182 rows
# [INFO] Saved 8087 rows
# [INFO] Saved 7902 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 8024 rows
# [INFO] Saved 8402 rows
# [INFO] Saved 7578 rows
# [INFO] Saved 7927 rows
# [INFO] Saved 8159 rows
# [INFO] Saved 8170 rows
# [INFO] Saved 7935 rows
# [INFO] Saved 8275 rows
# [INFO] Saved 7741 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8521 rows
# [INFO] Saved 8531 rows
# [INFO] Saved 8210 rows
# [INFO] Saved 8269 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 8146 rows
# [INFO] Saved 7873 rows
# [INFO] Saved 8348 rows
# [INFO] Saved 8473 rows
# [INFO] Saved 8375 rows
# [INFO] Saved 8146 rows
# [INFO] Saved 8444 rows
# [INFO] Saved 8054 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8632 rows
# [INFO] Saved 8598 rows
# [INFO] Saved 8508 rows
# [INFO] Saved 8434 rows
# [INFO] Saved 8005 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 7888 rows
# [INFO] Saved 8132 rows
# [INFO] Saved 8415 rows
# [INFO] Saved 8107 rows
# [INFO] Saved 8184 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8326 rows
# [INFO] Saved 8316 rows
# [INFO] Saved 8516 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8570 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 8522 rows
# [INFO] Saved 8560 rows
# [INFO] Saved 8629 rows
# [INFO] Saved 8472 rows
# [INFO] Saved 8607 rows
# [INFO] Saved 8688 rows
# [INFO] Saved 8485 rows
# [INFO] Saved 8184 rows
# [INFO] Saved 8476 rows
# [INFO] Saved 7779 rows
# [INFO] Saved 8303 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 8449 rows
# [INFO] Saved 8140 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8440 rows
# [INFO] Saved 8136 rows
# [INFO] Saved 8515 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 7999 rows
# [INFO] Saved 8478 rows
# [INFO] Saved 8257 rows
# [INFO] Saved 8115 rows
# [INFO] Saved 8422 rows
# [INFO] Saved 8204 rows
# [INFO] Saved 8215 rows
# [INFO] Saved 8583 rows
# [INFO] Saved 8493 rows
# [INFO] Saved 8528 rows
# [INFO] Saved 8594 rows
# [INFO] Saved 8688 rows
# [INFO] Saved 8589 rows
# [INFO] Saved 7877 rows
# [INFO] Saved 8362 rows
# [INFO] Saved 8039 rows
# [INFO] Saved 8044 rows
# [INFO] Saved 8077 rows
# [INFO] Saved 8529 rows
# [INFO] Saved 8645 rows
# [INFO] Saved 8308 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8440 rows
# [INFO] Saved 8566 rows
# [INFO] Saved 8577 rows
# [INFO] Saved 8311 rows
# [INFO] Saved 8280 rows
# [INFO] Saved 8556 rows
# [INFO] Saved 8097 rows
# [INFO] Saved 8444 rows
# [INFO] Saved 8402 rows
# [INFO] Saved 8200 rows
# [INFO] Saved 8594 rows
# [INFO] Saved 8533 rows
# [INFO] Saved 8262 rows
# [INFO] Saved 8499 rows
# [INFO] Saved 8470 rows
# [INFO] Saved 8478 rows
# [INFO] Saved 8324 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 8470 rows
# [INFO] Saved 7649 rows
# [INFO] Saved 8150 rows
# [INFO] Saved 8071 rows
# [INFO] Saved 8308 rows
# [INFO] Saved 7978 rows
# [INFO] Saved 8587 rows
# [INFO] Saved 8603 rows
# [INFO] Saved 8460 rows
# [INFO] Saved 8283 rows
# [INFO] Saved 8659 rows
# [INFO] Saved 8584 rows
# [INFO] Saved 8406 rows
# [INFO] Saved 8469 rows
# [INFO] Saved 8323 rows
# [INFO] Saved 8524 rows
# [INFO] Saved 8450 rows
# [INFO] Saved 8326 rows
# [INFO] Saved 8442 rows
# [INFO] Saved 8492 rows
# [INFO] Saved 8449 rows
# [INFO] Saved 8521 rows
# [INFO] Saved 8386 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 8500 rows
# [INFO] Saved 8217 rows
# [INFO] Saved 8344 rows
# [INFO] Saved 8471 rows
# [INFO] Saved 8607 rows
# [INFO] Saved 8056 rows
# [INFO] Saved 8451 rows
# [INFO] Saved 8261 rows
# [INFO] Saved 8467 rows
# [INFO] Saved 8742 rows
# [INFO] Saved 8737 rows
# [INFO] Saved 8657 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 8206 rows
# [INFO] Saved 8535 rows
# [INFO] Saved 8335 rows
# [INFO] Saved 8516 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8099 rows
# [INFO] Saved 8361 rows
# [INFO] Saved 8091 rows
# [INFO] Saved 8492 rows
# [INFO] Saved 8505 rows
# [INFO] Saved 8220 rows
# [INFO] Saved 8459 rows
# [INFO] Saved 8554 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 8446 rows
# [INFO] Saved 8390 rows
# [INFO] Saved 8470 rows
# [INFO] Saved 8583 rows
# [INFO] Saved 8302 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8109 rows
# [INFO] Saved 8354 rows
# [INFO] Saved 8523 rows
# [INFO] Saved 8263 rows
# [INFO] Saved 8100 rows
# [INFO] Saved 8168 rows
# [INFO] Saved 8192 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8318 rows
# [INFO] Saved 8208 rows
# [INFO] Saved 8325 rows
# [INFO] Saved 8273 rows
# [INFO] Saved 8209 rows
# [INFO] Saved 8314 rows
# [INFO] Saved 8411 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 8437 rows
# [INFO] Saved 8382 rows
# [INFO] Saved 8149 rows
# [INFO] Saved 8423 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 7904 rows
# [INFO] Saved 7739 rows
# [INFO] Saved 7938 rows
# [INFO] Saved 8377 rows
# [INFO] Saved 8232 rows
# [INFO] Saved 7801 rows
# [INFO] Saved 8459 rows
# [INFO] Saved 8550 rows
# [INFO] Saved 8305 rows
# [INFO] Saved 8185 rows
# [INFO] Saved 8500 rows
# [INFO] Saved 8407 rows
# [INFO] Saved 7923 rows
# [INFO] Saved 8486 rows
# [INFO] Saved 8318 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8334 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8012 rows
# [INFO] Saved 8117 rows
# [INFO] Saved 8066 rows
# [INFO] Saved 8500 rows
# [INFO] Saved 8415 rows
# [INFO] Saved 8043 rows
# [INFO] Saved 8062 rows
# [INFO] Saved 8079 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 8473 rows
# [INFO] Saved 8297 rows
# [INFO] Saved 8243 rows
# [INFO] Saved 8137 rows
# [INFO] Saved 8323 rows
# [INFO] Saved 8381 rows
# [INFO] Saved 8004 rows
# [INFO] Saved 8258 rows
# [INFO] Saved 7967 rows
# [INFO] Saved 8445 rows
# [INFO] Saved 8216 rows
# [INFO] Saved 7956 rows
# [INFO] Saved 8200 rows
# [INFO] Saved 8162 rows
# [INFO] Saved 8269 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 8223 rows
# [INFO] Saved 8232 rows
# [INFO] Saved 8035 rows
# [INFO] Saved 8056 rows
# [INFO] Saved 7976 rows
# [INFO] Saved 7910 rows
# [INFO] Saved 7921 rows
# [INFO] Saved 8253 rows
# [INFO] Saved 8299 rows
# [INFO] Saved 7879 rows
# [INFO] Saved 8142 rows
# [INFO] Saved 8180 rows
# [INFO] Saved 8046 rows
# [INFO] Saved 7944 rows
# [INFO] Saved 7774 rows
# [INFO] Saved 7665 rows
# [INFO] Saved 7990 rows
# [INFO] Saved 8024 rows
# [INFO] Saved 8056 rows
# [INFO] Saved 7831 rows
# [INFO] Saved 8030 rows
# [INFO] Saved 7942 rows
# [INFO] Saved 8039 rows
# [INFO] Saved 8165 rows
# [INFO] Saved 8398 rows
# [INFO] Saved 8372 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 7773 rows
# [INFO] Saved 8096 rows
# [INFO] Saved 8317 rows
# [INFO] Saved 8331 rows
# [INFO] Saved 8232 rows
# [INFO] Saved 7965 rows
# [INFO] Saved 8204 rows
# [INFO] Saved 8215 rows
# [INFO] Saved 8308 rows
# [INFO] Saved 8311 rows
# [INFO] Saved 8235 rows
# [INFO] Saved 8490 rows
# [INFO] Saved 8363 rows
# [INFO] Saved 8120 rows
# [INFO] Saved 8360 rows
# [INFO] Saved 8550 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8437 rows
# [INFO] Saved 7876 rows
# [INFO] Saved 8302 rows
# [INFO] Saved 8147 rows
# [INFO] Saved 8209 rows
# [INFO] Saved 8185 rows
# [INFO] Saved 8266 rows
# [INFO] Saved 8197 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8129 rows
# [INFO] Saved 8312 rows
# [INFO] Saved 8272 rows
# [INFO] Saved 8530 rows
# [INFO] Saved 8033 rows
# [INFO] Saved 8153 rows
# [INFO] Saved 7457 rows
# [INFO] Saved 8239 rows
# [INFO] Saved 7994 rows
# [INFO] Saved 8188 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 7835 rows
# [INFO] Saved 8188 rows
# [INFO] Saved 8276 rows
# [INFO] Saved 8242 rows
# [INFO] Saved 8113 rows
# [INFO] Saved 8009 rows
# [INFO] Saved 8184 rows
# [INFO] Saved 8563 rows
# [INFO] Saved 8231 rows
# [INFO] Saved 8403 rows
# [INFO] Saved 8528 rows
# [INFO] Saved 8345 rows
# [INFO] Saved 8532 rows
# [INFO] Saved 8348 rows
# [INFO] Saved 8255 rows
# [INFO] Saved 8477 rows
# [INFO] Saved 8277 rows
# [INFO] Saved 8308 rows
# [INFO] Saved 8512 rows
# [INFO] Saved 8306 rows
# [INFO] Saved 8034 rows
# [INFO] Saved 8168 rows
# [INFO] Saved 8654 rows
# [INFO] Saved 8309 rows
# [INFO] Saved 8220 rows
# [INFO] Saved 8206 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8374 rows
# [INFO] Saved 8323 rows
# [INFO] Saved 8353 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8414 rows
# [INFO] Saved 8160 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 8430 rows
# [INFO] Saved 8389 rows
# [INFO] Saved 8595 rows
# [INFO] Saved 8411 rows
# [INFO] Saved 8451 rows
# [INFO] Saved 8496 rows
# [INFO] Saved 8192 rows
# [INFO] Saved 8287 rows
# [INFO] Saved 7936 rows
# [INFO] Saved 9026 rows
# [INFO] Saved 8508 rows
# [INFO] Saved 8364 rows
# [INFO] Saved 8195 rows
# [INFO] Saved 8440 rows
# [INFO] Saved 8546 rows
# [INFO] Saved 8382 rows
# [INFO] Saved 8015 rows
# [INFO] Saved 7895 rows
# [INFO] Saved 8436 rows
# [INFO] Saved 8414 rows
# [INFO] Saved 8444 rows
# [INFO] Saved 8422 rows
# [INFO] Saved 8510 rows
# [INFO] Saved 8156 rows
# [INFO] Saved 8041 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8409 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 7853 rows
# [INFO] Saved 8133 rows
# [INFO] Saved 8166 rows
# [INFO] Saved 8448 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 7753 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 7977 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 8210 rows
# [INFO] Saved 8250 rows
# [INFO] Saved 8521 rows
# [INFO] Saved 8208 rows
# [INFO] Saved 8577 rows
# [INFO] Saved 8318 rows
# [INFO] Saved 8435 rows
# [INFO] Saved 8043 rows
# [INFO] Saved 8396 rows
# [INFO] Saved 8278 rows
# [INFO] Saved 8472 rows
# [INFO] Saved 8204 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 8081 rows
# [INFO] Saved 8457 rows
# [INFO] Saved 8065 rows
# [INFO] Saved 8030 rows
# [INFO] Saved 8223 rows
# [INFO] Saved 8143 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 8298 rows
# [INFO] Saved 8384 rows
# [INFO] Saved 8037 rows
# [INFO] Saved 8145 rows
# [INFO] Saved 8108 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8233 rows
# [INFO] Saved 8225 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8278 rows
# [INFO] Saved 8323 rows
# [INFO] Saved 8211 rows
# [INFO] Saved 8026 rows
# [INFO] Saved 8365 rows
# [INFO] Saved 8351 rows
# [INFO] Saved 8189 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8333 rows
# [INFO] Saved 8494 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8375 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8413 rows
# [INFO] Saved 8328 rows
# [INFO] Saved 8218 rows
# [INFO] Saved 7853 rows
# [INFO] Saved 8234 rows
# [INFO] Saved 8357 rows
# [INFO] Saved 8210 rows
# [INFO] Saved 8215 rows
# [INFO] Saved 7801 rows
# [INFO] Saved 8198 rows
# [INFO] Saved 8071 rows
# [INFO] Saved 7766 rows
# [INFO] Saved 8378 rows
# [INFO] Saved 8326 rows
# [INFO] Saved 8302 rows
# [INFO] Saved 8537 rows
# [INFO] Saved 9015 rows
# [INFO] Saved 8023 rows
# [INFO] Saved 9335 rows
# [INFO] Saved 8373 rows
# [INFO] Saved 9217 rows
# [INFO] Saved 9912 rows
# [INFO] Saved 9594 rows
# [INFO] Saved 8835 rows
# [INFO] Saved 9631 rows
# [INFO] Saved 9926 rows
# [INFO] Saved 8944 rows
# [INFO] Saved 8033 rows
# [INFO] Saved 8308 rows
# [INFO] Saved 9294 rows
# [INFO] Saved 9439 rows
# [INFO] Saved 9610 rows
# [INFO] Saved 9857 rows
# [INFO] Saved 9808 rows
# [INFO] Saved 9680 rows
# [INFO] Saved 9748 rows
# [INFO] Saved 9963 rows
# [INFO] Saved 8559 rows
# [INFO] Saved 9365 rows
# [INFO] Saved 9925 rows
# [INFO] Saved 9970 rows
# [INFO] Saved 9741 rows
# [INFO] Saved 9647 rows
# [INFO] Saved 9932 rows
# [INFO] Saved 9914 rows
# [INFO] Saved 9966 rows
# [INFO] Saved 9658 rows
# [INFO] Saved 9291 rows
# [INFO] Saved 8598 rows
# [INFO] Saved 8610 rows
# [INFO] Saved 9468 rows
# [INFO] Saved 9902 rows
# [INFO] Saved 9893 rows
# [INFO] Saved 9991 rows
# [INFO] Saved 9584 rows
# [INFO] Saved 9944 rows
# [INFO] Saved 9686 rows
# [INFO] Saved 9993 rows
# [INFO] Saved 9961 rows
# [INFO] Saved 9625 rows
# [INFO] Saved 9021 rows
# [INFO] Saved 9921 rows
# [INFO] Saved 9969 rows
# [INFO] Saved 9920 rows
# [INFO] Saved 9903 rows
# [INFO] Saved 8933 rows
# [INFO] Saved 8354 rows
# [INFO] Saved 8527 rows
# [INFO] Saved 8053 rows
# [INFO] Saved 8418 rows
# [INFO] Saved 8437 rows
# [INFO] Saved 8197 rows
# [INFO] Saved 8203 rows
# [INFO] Saved 8374 rows
# [INFO] Saved 8473 rows
# [INFO] Saved 8306 rows
# [INFO] Saved 8497 rows
# [INFO] Saved 7009 rows
# [INFO] Saved 8151 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 8216 rows
# [INFO] Saved 8365 rows
# [INFO] Saved 7824 rows
# [INFO] Saved 8210 rows
# [INFO] Saved 8330 rows
# [INFO] Saved 8424 rows
# [INFO] Saved 8438 rows
# [INFO] Saved 8391 rows
# [INFO] Saved 7930 rows
# [INFO] Saved 8293 rows
# [INFO] Saved 8239 rows
# [INFO] Saved 7512 rows
# [INFO] Saved 8342 rows
# [INFO] Saved 7676 rows
# [INFO] Saved 7662 rows
# [INFO] Saved 8183 rows
# [INFO] Saved 7841 rows
# [INFO] Saved 8266 rows
# [INFO] Saved 7746 rows
# [INFO] Saved 8219 rows
# [INFO] Saved 7432 rows
# [INFO] Saved 8421 rows
# [INFO] Saved 8128 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8156 rows
# [INFO] Saved 8375 rows
# [INFO] Saved 8328 rows
# [INFO] Saved 7919 rows
# [INFO] Saved 8083 rows
# [INFO] Saved 7968 rows
# [INFO] Saved 8162 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 8337 rows
# [INFO] Saved 8490 rows
# [INFO] Saved 8301 rows
# [INFO] Saved 8367 rows
# [INFO] Saved 8468 rows
# [INFO] Saved 8459 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8134 rows
# [INFO] Saved 8449 rows
# [INFO] Saved 8165 rows
# [INFO] Saved 8186 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 8528 rows
# [INFO] Saved 8417 rows
# [INFO] Saved 8305 rows
# [INFO] Saved 8368 rows
# [INFO] Saved 8469 rows
# [INFO] Saved 8353 rows
# [INFO] Saved 8321 rows
# [INFO] Saved 8507 rows
# [INFO] Saved 8801 rows
# [INFO] Saved 8296 rows
# [INFO] Saved 7985 rows
# [INFO] Saved 8550 rows
# [INFO] Saved 8369 rows
# [INFO] Saved 8536 rows
# [INFO] Saved 8232 rows
# [INFO] Saved 8509 rows
# [INFO] Saved 8273 rows
# [INFO] Saved 8381 rows
# [INFO] Saved 8301 rows
# [INFO] Saved 8155 rows
# [INFO] Saved 8425 rows
# [INFO] Saved 7723 rows
# [INFO] Saved 8484 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 8442 rows
# [INFO] Saved 8062 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8193 rows
# [INFO] Saved 8281 rows
# [INFO] Saved 8191 rows
# [INFO] Saved 8345 rows
# [INFO] Saved 8193 rows
# [INFO] Saved 8139 rows
# [INFO] Saved 8058 rows
# [INFO] Saved 8312 rows
# [INFO] Saved 8385 rows
# [INFO] Saved 8123 rows
# [INFO] Saved 8380 rows
# [INFO] Saved 8096 rows
# [INFO] Saved 8671 rows
# [INFO] Saved 8451 rows
# [INFO] Saved 8281 rows
# [INFO] Saved 8255 rows
# [INFO] Saved 8367 rows
# [INFO] Saved 7941 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 8377 rows
# [INFO] Saved 8249 rows
# [INFO] Saved 8014 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 7805 rows
# [INFO] Saved 8100 rows
# [INFO] Saved 8014 rows
# [INFO] Saved 8016 rows
# [INFO] Saved 7914 rows
# [INFO] Saved 8332 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8132 rows
# [INFO] Saved 7993 rows
# [INFO] Saved 8476 rows
# [INFO] Saved 8292 rows
# [INFO] Saved 8442 rows
# [INFO] Saved 7849 rows
# [INFO] Saved 8274 rows
# [INFO] Saved 8001 rows
# [INFO] Saved 8245 rows
# [INFO] Saved 8223 rows
# [INFO] Saved 8133 rows
# [INFO] Saved 8047 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8120 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 7995 rows
# [INFO] Saved 8117 rows
# [INFO] Saved 8208 rows
# [INFO] Saved 8004 rows
# [INFO] Saved 8099 rows
# [INFO] Saved 8166 rows
# [INFO] Saved 7783 rows
# [INFO] Saved 8225 rows
# [INFO] Saved 7903 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8040 rows
# [INFO] Saved 7987 rows
# [INFO] Saved 8540 rows
# [INFO] Saved 8309 rows
# [INFO] Saved 8047 rows
# [INFO] Saved 8411 rows
# [INFO] Saved 8201 rows
# [INFO] Saved 8357 rows
# [INFO] Saved 8355 rows
# [INFO] Saved 8502 rows
# [INFO] Saved 8388 rows
# [INFO] Saved 8414 rows
# [INFO] Saved 8446 rows
# [INFO] Saved 8535 rows
# [INFO] Saved 8449 rows
# [INFO] Saved 8233 rows
# [INFO] Saved 8372 rows
# [INFO] Saved 8351 rows
# [INFO] Saved 8771 rows
# [INFO] Saved 8422 rows
# [INFO] Saved 8225 rows
# [INFO] Saved 8210 rows
# [INFO] Saved 8264 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8293 rows
# [INFO] Saved 8514 rows
# [INFO] Saved 8318 rows
# [INFO] Saved 8256 rows
# [INFO] Saved 8321 rows
# [INFO] Saved 8079 rows
# [INFO] Saved 8328 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 9351 rows
# [INFO] Saved 9447 rows
# [INFO] Saved 9365 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8732 rows
# [INFO] Saved 9575 rows
# [INFO] Saved 9415 rows
# [INFO] Saved 8707 rows
# [INFO] Saved 9308 rows
# [INFO] Saved 9268 rows
# [INFO] Saved 8711 rows
# [INFO] Saved 9193 rows
# [INFO] Saved 8762 rows
# [INFO] Saved 8967 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 8973 rows
# [INFO] Saved 9250 rows
# [INFO] Saved 9770 rows
# [INFO] Saved 9363 rows
# [INFO] Saved 8961 rows
# [INFO] Saved 9330 rows
# [INFO] Saved 9498 rows
# [INFO] Saved 9449 rows
# [INFO] Saved 9406 rows
# [INFO] Saved 8800 rows
# [INFO] Saved 9126 rows
# [INFO] Saved 9584 rows
# [INFO] Saved 9088 rows
# [INFO] Saved 9648 rows
# [INFO] Saved 9637 rows
# [INFO] Saved 8989 rows
# [INFO] Saved 9423 rows
# [INFO] Saved 9275 rows
# [INFO] Saved 9527 rows
# [INFO] Saved 8709 rows
# [INFO] Saved 9335 rows
# [INFO] Saved 8915 rows
# [INFO] Saved 8331 rows
# [INFO] Saved 9089 rows
# [INFO] Saved 9591 rows
# [INFO] Saved 9162 rows
# [INFO] Saved 9211 rows
# [INFO] Saved 9145 rows
# [INFO] Saved 8081 rows
# [INFO] Saved 9365 rows
# [INFO] Saved 9442 rows
# [INFO] Saved 8768 rows
# [INFO] Saved 9421 rows
# [INFO] Saved 8391 rows
# [INFO] Saved 8854 rows
# [INFO] Saved 8859 rows
# [INFO] Saved 8938 rows
# [INFO] Saved 8594 rows
# [INFO] Saved 8574 rows
# [INFO] Saved 7982 rows
# [INFO] Saved 8014 rows
# [INFO] Saved 8105 rows
# [INFO] Saved 8302 rows
# [INFO] Saved 8343 rows
# [INFO] Saved 8124 rows
# [INFO] Saved 8355 rows
# [INFO] Saved 8400 rows
# [INFO] Saved 8196 rows
# [INFO] Saved 8086 rows
# [INFO] Saved 8342 rows
# [INFO] Saved 8325 rows
# [INFO] Saved 8297 rows
# [INFO] Saved 8276 rows
# [INFO] Saved 8399 rows
# [INFO] Saved 8158 rows
# [INFO] Saved 8041 rows
# [INFO] Saved 8474 rows
# [INFO] Saved 8191 rows
# [INFO] Saved 8427 rows
# [INFO] Saved 8478 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8039 rows
# [INFO] Saved 8159 rows
# [INFO] Saved 8484 rows
# [INFO] Saved 8249 rows
# [INFO] Saved 8120 rows
# [INFO] Saved 8244 rows
# [INFO] Saved 8417 rows
# [INFO] Saved 7918 rows
# [INFO] Saved 7913 rows
# [INFO] Saved 7976 rows
# [INFO] Saved 8166 rows
# [INFO] Saved 8212 rows
# [INFO] Saved 8372 rows
# [INFO] Saved 8404 rows
# [INFO] Saved 8396 rows
# [INFO] Saved 8449 rows
# [INFO] Saved 8385 rows
# [INFO] Saved 8311 rows
# [INFO] Saved 8270 rows
# [INFO] Saved 8120 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8235 rows
# [INFO] Saved 8280 rows
# [INFO] Saved 7958 rows
# [INFO] Saved 8322 rows
# [INFO] Saved 7838 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 7967 rows
# [INFO] Saved 8152 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8285 rows
# [INFO] Saved 8610 rows
# [INFO] Saved 8451 rows
# [INFO] Saved 8503 rows
# [INFO] Saved 8112 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 8217 rows
# [INFO] Saved 7680 rows
# [INFO] Saved 7941 rows
# [INFO] Saved 8229 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 8394 rows
# [INFO] Saved 8054 rows
# [INFO] Saved 8167 rows
# [INFO] Saved 8447 rows
# [INFO] Saved 8055 rows
# [INFO] Saved 8092 rows
# [INFO] Saved 8054 rows
# [INFO] Saved 8194 rows
# [INFO] Saved 8111 rows
# [INFO] Saved 8363 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 8402 rows
# [INFO] Saved 8151 rows
# [INFO] Saved 8204 rows
# [INFO] Saved 8121 rows
# [INFO] Saved 8045 rows
# [INFO] Saved 8292 rows
# [INFO] Saved 8087 rows
# [INFO] Saved 7870 rows
# [INFO] Saved 8162 rows
# [INFO] Saved 9277 rows
# [INFO] Saved 8244 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 8412 rows
# [INFO] Saved 8305 rows
# [INFO] Saved 8440 rows
# [INFO] Saved 8363 rows
# [INFO] Saved 8403 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 7923 rows
# [INFO] Saved 8032 rows
# [INFO] Saved 8028 rows
# [INFO] Saved 8007 rows
# [INFO] Saved 8141 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8154 rows
# [INFO] Saved 8248 rows
# [INFO] Saved 8644 rows
# [INFO] Saved 8340 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8168 rows
# [INFO] Saved 8065 rows
# [INFO] Saved 8348 rows
# [INFO] Saved 8364 rows
# [INFO] Saved 8224 rows
# [INFO] Saved 8065 rows
# [INFO] Saved 8298 rows
# [INFO] Saved 8314 rows
# [INFO] Saved 8046 rows
# [INFO] Saved 8070 rows
# [INFO] Saved 8024 rows
# [INFO] Saved 8795 rows
# [INFO] Saved 8656 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 8245 rows
# [INFO] Saved 8606 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8156 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 8025 rows
# [INFO] Saved 8360 rows
# [INFO] Saved 8067 rows
# [INFO] Saved 8493 rows
# [INFO] Saved 8460 rows
# [INFO] Saved 8245 rows
# [INFO] Saved 8305 rows
# [INFO] Saved 8470 rows
# [INFO] Saved 8483 rows
# [INFO] Saved 8335 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 8299 rows
# [INFO] Saved 8741 rows
# [INFO] Saved 8355 rows
# [INFO] Saved 8280 rows
# [INFO] Saved 8243 rows
# [INFO] Saved 8581 rows
# [INFO] Saved 8176 rows
# [INFO] Saved 8273 rows
# [INFO] Saved 8204 rows
# [INFO] Saved 8446 rows
# [INFO] Saved 8919 rows
# [INFO] Saved 8377 rows
# [INFO] Saved 8040 rows
# [INFO] Saved 8372 rows
# [INFO] Saved 7973 rows
# [INFO] Saved 8128 rows
# [INFO] Saved 8136 rows
# [INFO] Saved 7950 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 8063 rows
# [INFO] Saved 8064 rows
# [INFO] Saved 6341 rows
# [INFO] Saved 7315 rows
# [INFO] Saved 6778 rows
# [INFO] Saved 7757 rows
# [INFO] Saved 7710 rows
# [INFO] Saved 7655 rows
# [INFO] Saved 8084 rows
# [INFO] Saved 7911 rows
# [INFO] Saved 7599 rows
# [INFO] Saved 8143 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8053 rows
# [INFO] Saved 7945 rows
# [INFO] Saved 8230 rows
# [INFO] Saved 7858 rows
# [INFO] Saved 7975 rows
# [INFO] Saved 7950 rows
# [INFO] Saved 7731 rows
# [INFO] Saved 7436 rows
# [INFO] Saved 8148 rows
# [INFO] Saved 8282 rows
# [INFO] Saved 7802 rows
# [INFO] Saved 7203 rows
# [INFO] Saved 6999 rows
# [INFO] Saved 7875 rows
# [INFO] Saved 7994 rows
# [INFO] Saved 7844 rows
# [INFO] Saved 8094 rows
# [INFO] Saved 8064 rows
# [INFO] Saved 8176 rows
# [INFO] Saved 8390 rows
# [INFO] Saved 8214 rows
# [INFO] Saved 8261 rows
# [INFO] Saved 8297 rows
# [INFO] Saved 8075 rows
# [INFO] Saved 8116 rows
# [INFO] Saved 8094 rows
# [INFO] Saved 8095 rows
# [INFO] Saved 7899 rows
# [INFO] Saved 8288 rows
# [INFO] Saved 7928 rows
# [INFO] Saved 8051 rows
# [INFO] Saved 8107 rows
# [INFO] Saved 7904 rows
# [INFO] Saved 7937 rows
# [INFO] Saved 7895 rows
# [INFO] Saved 8066 rows
# [INFO] Saved 8079 rows
# [INFO] Saved 8292 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 8389 rows
# [INFO] Saved 8076 rows
# [INFO] Saved 8013 rows
# [INFO] Saved 8122 rows
# [INFO] Saved 8198 rows
# [INFO] Saved 8344 rows
# [INFO] Saved 8257 rows
# [INFO] Saved 8376 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8267 rows
# [INFO] Saved 8419 rows
# [INFO] Saved 8232 rows
# [INFO] Saved 7906 rows
# [INFO] Saved 8281 rows
# [INFO] Saved 8263 rows
# [INFO] Saved 8326 rows
# [INFO] Saved 8306 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8207 rows
# [INFO] Saved 8289 rows
# [INFO] Saved 8124 rows
# [INFO] Saved 8172 rows
# [INFO] Saved 8237 rows
# [INFO] Saved 8271 rows
# [INFO] Saved 8101 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 8104 rows
# [INFO] Saved 8387 rows
# [INFO] Saved 7845 rows
# [INFO] Saved 8220 rows
# [INFO] Saved 8410 rows
# [INFO] Saved 8208 rows
# [INFO] Saved 8282 rows
# [INFO] Saved 8144 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8228 rows
# [INFO] Saved 8169 rows
# [INFO] Saved 8199 rows
# [INFO] Saved 8464 rows
# [INFO] Saved 8338 rows
# [INFO] Saved 8539 rows
# [INFO] Saved 8558 rows
# [INFO] Saved 8371 rows
# [INFO] Saved 8347 rows
# [INFO] Saved 8436 rows
# [INFO] Saved 8509 rows
# [INFO] Saved 8510 rows
# [INFO] Saved 8174 rows
# [INFO] Saved 7777 rows
# [INFO] Saved 8254 rows
# [INFO] Saved 8042 rows
# [INFO] Saved 8170 rows
# [INFO] Saved 8273 rows
# [INFO] Saved 8290 rows
# [INFO] Saved 8010 rows
# [INFO] Saved 8417 rows
# [INFO] Saved 8361 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8623 rows
# [INFO] Saved 8260 rows
# [INFO] Saved 7905 rows
# [INFO] Saved 8238 rows
# [INFO] Saved 8272 rows
# [INFO] Saved 7161 rows
# [INFO] Saved 8138 rows
# [INFO] Saved 6907 rows
# [INFO] Saved 8163 rows
# [INFO] Saved 8065 rows
# [INFO] Saved 8435 rows
# [INFO] Saved 8312 rows
# [INFO] Saved 8415 rows
# [INFO] Saved 7973 rows
# [INFO] Saved 8080 rows
# [INFO] Saved 8336 rows
# [INFO] Saved 8310 rows
# [INFO] Saved 8202 rows
# [INFO] Saved 8252 rows
# [INFO] Saved 8155 rows
# [INFO] Saved 8458 rows
# [INFO] Saved 8303 rows
# [INFO] Saved 8032 rows
# [INFO] Saved 8392 rows
# [INFO] Saved 8332 rows
# [INFO] Saved 8277 rows
# [INFO] Saved 8404 rows
# [INFO] Saved 7997 rows
# [INFO] Saved 7795 rows
# [INFO] Saved 7763 rows
# [INFO] Saved 8253 rows
# [INFO] Saved 8052 rows
# [INFO] Saved 8241 rows
# [INFO] Saved 7892 rows
# [INFO] Saved 8298 rows
# [INFO] Saved 8316 rows
# [INFO] Saved 8313 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 8356 rows
# [INFO] Saved 8226 rows
# [INFO] Saved 7927 rows
# [INFO] Saved 8112 rows
# [INFO] Saved 8439 rows
# [INFO] Saved 8209 rows
# [INFO] Saved 8626 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8125 rows
# [INFO] Saved 8392 rows
# [INFO] Saved 8443 rows
# [INFO] Saved 8240 rows
# [INFO] Saved 8456 rows
# [INFO] Saved 8480 rows
# [INFO] Saved 8409 rows
# [INFO] Saved 8216 rows
# [INFO] Saved 8369 rows
# [INFO] Saved 8110 rows
# [INFO] Saved 8106 rows
# [INFO] Saved 8078 rows
# [INFO] Saved 8234 rows
# [INFO] Saved 8634 rows
# [INFO] Saved 8379 rows
# [INFO] Saved 8297 rows
# [INFO] Saved 8358 rows
# [INFO] Saved 8333 rows
# [INFO] Saved 8329 rows
# [INFO] Saved 8294 rows
# [INFO] Saved 8282 rows
# [INFO] Saved 7959 rows
# [INFO] Saved 8118 rows
# [INFO] Saved 8116 rows
# [INFO] Saved 8314 rows
# [INFO] Saved 8040 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 8142 rows
# [INFO] Saved 8039 rows
# [INFO] Saved 8256 rows
# [INFO] Saved 7918 rows
# [INFO] Saved 8126 rows
# [INFO] Saved 8137 rows
# [INFO] Saved 8332 rows
# [INFO] Saved 5783 rows
# [INFO] Saved 8421 rows
# [INFO] Saved 8363 rows
# [INFO] Saved 8349 rows
# [INFO] Saved 8417 rows
# [INFO] Saved 7948 rows
# [INFO] Saved 7961 rows
# [INFO] Saved 8268 rows
# [INFO] Saved 7664 rows
# [INFO] Saved 7902 rows
# [INFO] Saved 7503 rows
# [INFO] Saved 8265 rows
# [INFO] Saved 8356 rows
# [INFO] Saved 8048 rows
# [INFO] Saved 8326 rows
# [INFO] Saved 8506 rows
# [INFO] Saved 8176 rows
# [INFO] Saved 7933 rows
# [INFO] Saved 8358 rows
# [INFO] Saved 8246 rows
# [INFO] Saved 8379 rows
# [INFO] Saved 8460 rows
# [INFO] Saved 7830 rows
# [INFO] Saved 8461 rows
# [INFO] Saved 7890 rows
# [INFO] Saved 8127 rows
# [INFO] Saved 8112 rows
# [INFO] Saved 8204 rows
# [INFO] Saved 8297 rows
# [INFO] Saved 8147 rows
# [INFO] Saved 8140 rows
# [INFO] Saved 8325 rows
# [INFO] Saved 8269 rows
# [INFO] Saved 8113 rows
# [INFO] Saved 7720 rows
# [INFO] Saved 8171 rows
# [INFO] Saved 8212 rows
# [INFO] Saved 8358 rows
# [INFO] Saved 8351 rows
# [INFO] Saved 7893 rows
# [INFO] Saved 6879 rows
# [INFO] Saved 8149 rows
# [INFO] Saved 8285 rows
# [INFO] Saved 8301 rows
# [INFO] Saved 8304 rows
# [INFO] Saved 7952 rows
# [INFO] Saved 8266 rows
# [INFO] Saved 8251 rows
# [INFO] Saved 8154 rows
# [INFO] Saved 8234 rows
# [INFO] Saved 8448 rows
# [INFO] Saved 8263 rows
# [INFO] Saved 8256 rows
# [INFO] Saved 7755 rows
# [INFO] Saved 8205 rows
# [INFO] Saved 7985 rows
# [INFO] Saved 8366 rows
# [INFO] Saved 8138 rows
# [INFO] Saved 8203 rows
# [INFO] Saved 8246 rows
# [INFO] Saved 8132 rows
# [INFO] Saved 8220 rows
# [INFO] Saved 8181 rows
# [INFO] Saved 8228 rows
# [INFO] Saved 8293 rows
# [INFO] Saved 8584 rows
# [INFO] Saved 8022 rows
# [INFO] Saved 8094 rows
# [INFO] Saved 7833 rows
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#       9 mode = "w" if first_chunk else "a"  # Write first time, then append
#      10 header = first_chunk  # Write header only once
# ---> 12 chunk.to_csv(PREPROCESSED_CSV, mode=mode, header=header, index=False)
#      13 first_chunk = False  # After first write, switch to append mode
#      14 print(f"[INFO] Saved {len(chunk)} rows")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\formats\csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#     327     self.nlevels,
#     328     self.cols,
#     329     self.writer,
#     330 )
#
# File writers.pyx:73, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
